# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path = os.path.expanduser('~/REPOS/datalab/code')

s0 = np.loadtxt(path+'/signal0.txt')
s1 = np.loadtxt(path+'/signal1.txt')
s2= np.loadtxt(path+'/signal2.txt')

probe = np.loadtxt(path+'/probe0.txt')

print(len(s0[:,0]))
print(s0)
#plt.plot(s0[:,0], s0[:,1])
fig = plt.figure(figsize=(15,5))
fig.subplots_adjust(hspace=1)
gs = fig.add_gridspec(6,6)
ax0, ax1, ax2 = [fig.add_subplot(gs[:2,:]),
                 fig.add_subplot(gs[2:4,:]),
                 fig.add_subplot(gs[4:,:])
                ]

ax0.plot(s0[:,0], s0[:,1])
ax1.plot(s1[:,0], s1[:,1])
ax2.plot(s2[:,0], s2[:,1])
# Out:
# 1000
# [[ 0.         0.0406443]
#  [ 0.005     -0.0400859]
#  [ 0.01      -0.0288883]
#  ...
#  [ 4.9850001 -0.0491803]
#  [ 4.9899998  0.0366574]
#  [ 4.9949999 -0.0858189]]

# %%
print(probe)
plt.scatter(probe[:,0], probe[:,2])
plt.xlim(0, 5)
# Out:
# [[0.00000e+00 0.00000e+00 1.05299e-01]
#  [2.00000e-01 0.00000e+00 1.72490e+01]
#  [4.00000e-01 0.00000e+00 8.35607e+00]
#  ...
#  [1.99400e+02 0.00000e+00 0.00000e+00]
#  [1.99600e+02 0.00000e+00 0.00000e+00]
#  [1.99800e+02 0.00000e+00 0.00000e+00]]
# (0.0, 5.0)
